# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("weightdataset.csv") 
data.tail()
# Out:
#       Gender     Height      Weight
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
scaling=StandardScaler()

# %%
height=scaling.fit_transform(data[['Height']])
weight=scaling.fit_transform(data[['Weight']])
plt.plot(height,weight,'.')
plt.show()

# %%
x_mean= np.mean(weight)
y_mean= np.mean(height)

num=0 #the numerator
den=0 #the denomitor

# %%
for i in range(len(x)):
    num += (weight[i]-x_mean)*(height[i]-y_mean)
    den += (weight[i]-x_mean**2)
    
m= num/den
c=y_mean-m*x_mean

print(m,c)
# Out:
# [3.51128246e+15] [1.63709046e-15]

# %%
y_pred = m* weight + c
y_pred=scaling.fit_transform(y_pred)
plt.plot(weight,height,'.')
plt.plot([min(weight),max(weight)], [min(y_pred), max(y_pred)])
plt.title("Height vs Weight")
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\201705648\\Anaconda3\\anaconda new\\lib\\site-packages\\matplotlib\\pyplot.py'>
